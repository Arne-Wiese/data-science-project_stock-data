# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time

# Replace 'YOUR_API_KEY' with your actual Alpha Vantage API key
API_KEY = 'JB01QMIO6Y6OVRTD'
BASE_URL = 'https://www.alphavantage.co/query'

# %%
def fetch_data(symbol, function, **params):
    params['function'] = function
    params['symbol'] = symbol
    params['apikey'] = API_KEY
    response = requests.get(BASE_URL, params=params)
    data = response.json()
    return data

# %%
def symbol_data_to_data_frame(data):
    df = pd.DataFrame(data).T
    df.index = pd.to_datetime(df.index)
    df['5. adjusted close'] = df['5. adjusted close'].astype(float)
    return df

# %%
def line_plot_symbol_df(df, titel, x, y):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['5. adjusted close'])
    plt.title(titel)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.grid(True)
    plt.show()

# %%
# List of sector symbols
sectors = [
    "XLC",  # Communication Services
    "XLY",  # Consumer Discretionary
    "XLP",  # Consumer Staples
    "XLE",  # Energy
    "XLF",  # Financials
    "XLV",  # Health Care
    "XLI",  # Industrials
    "XLB",  # Materials
    "XLRE", # Real Estate
    "XLK",  # Technology
    "XLU",  # Utilities
]

# %%
def fetch_sector_data():
    # Dictionary to store sector data
    sector_data = {}

    #non-premium couter
    i = 0

    # Loop through sectors and make API requests
    for sector in sectors:
        data = fetch_data(sector, "TIME_SERIES_MONTHLY_ADJUSTED" )
        if len(data) > 1:
            sector_data[sector] = data['Monthly Adjusted Time Series']
        else:
            #exception for data fetch error
            raise Exception("data fetch error" + ' ' + data['Note'])
        #non-premium delay
        i += 1
        if i == 5:
            time.sleep(60)
            i=0
    return sector_data
sector_data = fetch_sector_data()
print(sector_data)
# Out:
# {'XLC': {'2023-09-01': {'1. open': '67.9500', '2. high': '67.9500', '3. low': '66.9228', '4. close': '67.1000', '5. adjusted close': '67.1000', '6. volume': '4034582', '7. dividend amount': '0.0000'}, '2023-08-31': {'1. open': '68.4200', '2. high': '68.9200', '3. low': '64.3150', '4. close': '67.7300', '5. adjusted close': '67.7300', '6. volume': '121411440', '7. dividend amount': '0.0000'}, '2023-07-31': {'1. open': '64.8700', '2. high': '69.2200', '3. low': '64.5250', '4. close': '68.7900', '5. adjusted close': '68.7900', '6. volume': '124113723', '7. dividend amount': '0.0000'}, '2023-06-30': {'1. open': '62.4200', '2. high': '65.6100', '3. low': '62.2800', '4. close': '65.0800', '5. adjusted close': '65.0800', '6. volume': '123494649', '7. dividend amount': '0.1049'}, '2023-05-31': {'1. open': '59.8100', '2. high': '62.7200', '3. low': '57.4300', '4. close': '62.2400', '5. adjusted close': '62.1387', '6. volume': '136868565', '7. dividend amount': '0.0000'}, '2023-04-28': {'1. open': '57.5500', '2. high': '59.9100', '3. low': '56.0650', '4. close': '59.9000', '5. adjusted close': '59.8025', '6. volume': '141198453', '7. dividend amount': '0.0000'}, '2023-03-31': {'1. open': '53.4000', '2. high': '58.0200', '3. low': '51.3700', '4. close': '57.9700', '5. adjusted close': '57.8757', '6. volume': '173983519', '7. dividend amount': '0.1500'}, '2023-02-28': {'1. open': '54.6900', '2. high': '59.7900', '3. low': '52.8450', '4. close': '53.5000', '5. adjusted close': '53.2684', '6. volume': '105301744', '7. dividend amount': '0.0000'}, '2023-01-31': {'1. open': '48.5800', '2. high': '55.5957', '3. low': '48.1500', '4. close': '55.0800', '5. adjusted close': '54.8415', '6. volume': '109556553', '7. dividend amount': '0.0000'}, '2022-12-30': {'1. open': '51.6100', '2. high': '52.1900', '3. low': '46.4750', '4. close': '47.9900', '5. adjusted close': '47.7822', '6. volume': '124573043', '7. dividend amount': '0.1177'}, '2022-11-30': {'1. open': '48.8400', '2. high': '51.5250', '3. low': '44.8600', '4. close': '51.5100', '5. adjusted close': '51.1584', '6. volume': '137291234', '7. dividend amount': '0.0000'}, '2022-10-31': {'1. open': '48.4400', '2. high': '51.9500', '3. low': '46.4730', '4. close': '48.2100', '5. adjusted close': '47.8809', '6. volume': '143915524', '7. dividend amount': '0.0000'}, '2022-09-30': {'1. open': '54.2400', '2. high': '56.2350', '3. low': '47.8000', '4. close': '47.8900', '5. adjusted close': '47.5631', '6. volume': '152722485', '7. dividend amount': '0.1095'}, '2022-08-31': {'1. open': '55.9500', '2. high': '60.2400', '3. low': '53.8900', '4. close': '54.3800', '5. adjusted close': '53.8960', '6. volume': '84052834', '7. dividend amount': '0.0000'}, '2022-07-29': {'1. open': '54.0800', '2. high': '58.3350', '3. low': '53.4100', '4. close': '56.3700', '5. adjusted close': '55.8683', '6. volume': '84925132', '7. dividend amount': '0.0000'}, '2022-06-30': {'1. open': '60.6500', '2. high': '61.0362', '3. low': '52.7350', '4. close': '54.2700', '5. adjusted close': '53.7870', '6. volume': '121464925', '7. dividend amount': '0.1299'}, '2022-05-31': {'1. open': '59.1800', '2. high': '63.0900', '3. low': '55.6800', '4. close': '60.1800', '5. adjusted close': '59.5015', '6. volume': '191634974', '7. dividend amount': '0.0000'}, '2022-04-29': {'1. open': '69.1100', '2. high': '71.5700', '3. low': '58.4300', '4. close': '59.0600', '5. adjusted close': '58.3941', '6. volume': '150932423', '7. dividend amount': '0.0000'}, '2022-03-31': {'1. open': '68.1400', '2. high': '70.8100', '3. low': '63.4900', '4. close': '68.7800', '5. adjusted close': '68.0045', '6. volume': '138810506', '7. dividend amount': '0.1727'}, '2022-02-28': {'1. open': '74.0000', '2. high': '76.5700', '3. low': '64.0300', '4. close': '68.4500', '5. adjusted close': '67.5053', '6. volume': '129918845', '7. dividend amount': '0.0000'}, '2022-01-31': {'1. open': '77.8600', '2. high': '78.7300', '3. low': '69.4800', '4. close': '73.9500', '5. adjusted ...

# %%
# Convert sector data to pandas DataFrames
def sector_to_data_frame():
    sector_dfs = {}
    for sector, data in sector_data.items():
        df = pd.DataFrame(data).T
        df.index = pd.to_datetime(df.index)
        df['5. adjusted close'] = df['5. adjusted close'].astype(float)
        sector_dfs[sector] = df#.head(15)  # Extract the first 15 rows
    return sector_dfs

sector_dfs = sector_to_data_frame()

# %%
# Create a line plot for each sector's adjusted close values
def line_plot_sectors():
    plt.figure(figsize=(12, 6))
    for sector, df in sector_dfs.items():
        plt.plot(df.index, df['5. adjusted close'], label=sector)

    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title("Adjusted Closing Prices of Stock Market Sectors")
    plt.legend()
    plt.grid(True)
    plt.show()

line_plot_sectors()

# %%
def heatmap_sectors():  
    # Combine the opening prices into a single DataFrame
    combined_df = pd.concat([df["5. adjusted close"] for df in sector_dfs.values()], axis=1)
    combined_df.columns = sectors

    # Calculate the correlation matrix
    correlation_matrix = combined_df.corr()

    # Create a heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
    plt.title("Correlation Heatmap of Sector Closing Prices")
    plt.show()
    
heatmap_sectors()

# %%
def fetch_sp500_data():
    data = fetch_data("SPY", "TIME_SERIES_MONTHLY_ADJUSTED")
    if len(data) > 1:
            sp500_data = data['Monthly Adjusted Time Series']
    else:
        #exception for data fetch error
        raise Exception("data fetch error" + ' ' + data['Note'])
    return sp500_data

sp500_data = fetch_sp500_data()

# %%
sp500_df = symbol_data_to_data_frame(sp500_data)
print(sp500_df)
# Out:
#              1. open   2. high    3. low  4. close 5. adjusted close  \
# 2023-09-01  453.1700  453.6700  449.6800  451.1900          451.1900
# 2023-08-31  456.2700  457.2500  433.0100  450.3500          450.3500
# 2023-07-31  442.9200  459.4400  437.0600  457.7900          457.7900
# 2023-06-30  418.0900  444.3000  416.7900  443.2800          443.2800
# 2023-05-31  415.4700  422.5800  403.7400  417.8500          416.2980
# ...              ...       ...       ...       ...               ...
# 2000-04-28  150.1250  153.1093  133.5000  145.0937           94.5360
# 2000-03-31  137.6250  155.7500  135.0312  150.3750           97.9770
# 2000-02-29  139.7500  144.5625  132.7187  137.4375           89.3222
# 2000-01-31  148.2500  148.2500  135.0000  139.5625           90.7032
# 1999-12-31  139.3125  147.5625  139.0000  146.8750           95.4557
#
#              6. volume 7. dividend amount
# 2023-09-01    58944098             0.0000
# 2023-08-31  1755315375             0.0000
# 2023-07-31  1374774872             0.0000
# 2023-06-30  1749958214             1.6384
# 2023-05-31  1776447412             0.0000
# ...                ...                ...
# 2000-04-28   229246200             0.0000
# 2000-03-31   247594900             0.3708
# 2000-02-29   186938300             0.0000
# 2000-01-31   156770800             0.0000
# 1999-12-31   121529300             0.3476
#
# [286 rows x 7 columns]

# %%
line_plot_symbol_df(sp500_df, "S&P 500 Index - Tägliche Schlusskurse (Linienplot)", "Datum", "Schlusskurs")

# %%
def market_percentage(sector_d, sp500_d):
    for symbol, data in sector_d.items():
        print(data)
        for date in data.index():
            print(date)
            data[date] = (data[date]['5. adjusted close']/ sp500_data[date]['5. adjusted close']) *100
    for date, values in sp500_d.items():
        sp500_d[date] = 100
    market_data = sector_d
    market_data["SPY"] = sp500_d
    return market_data

market_data = market_percentage(sector_dfs, sp500_df)
print(market_data)
# Out:
#             1. open  2. high   3. low 4. close  5. adjusted close  6. volume  \
# 2023-09-01  67.9500  67.9500  66.9228  67.1000            67.1000    4034582
# 2023-08-31  68.4200  68.9200  64.3150  67.7300            67.7300  121411440
# 2023-07-31  64.8700  69.2200  64.5250  68.7900            68.7900  124113723
# 2023-06-30  62.4200  65.6100  62.2800  65.0800            65.0800  123494649
# 2023-05-31  59.8100  62.7200  57.4300  62.2400            62.1387  136868565
# ...             ...      ...      ...      ...                ...        ...
# 2018-11-30  46.1900  46.7900  42.3800  45.0100            43.1670   53149541
# 2018-10-31  49.1700  49.2200  43.0700  46.0400            44.1548  115192982
# 2018-09-28  49.0500  49.5300  47.1700  49.0000            46.9936   44621850
# 2018-08-31  48.5600  50.0600  47.9000  49.1800            47.0387    6752829
# 2018-07-31  49.1100  52.1100  47.8690  48.4600            46.3500    8147373
#
#            7. dividend amount
# 2023-09-01             0.0000
# 2023-08-31             0.0000
# 2023-07-31             0.0000
# 2023-06-30             0.1049
# 2023-05-31             0.0000
# ...                       ...
# 2018-11-30             0.0000
# 2018-10-31             0.0000
# 2018-09-28             0.1317
# 2018-08-31             0.0000
# 2018-07-31             0.0000
#
# [63 rows x 7 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 13
#      10     market_data["SPY"] = sp500_d
#      11     return market_data
# ---> 13 market_data = market_percentage(sector_dfs, sp500_df)
#      14 print(market_data)
#
# Cell In[57], line 4, in market_percentage(sector_d, sp500_d)
#       2 for symbol, data in sector_d.items():
#       3     print(data)
# ----> 4     for date in data.index():
#       5         print(date)
#       6         data[date] = (data[date]['5. adjusted close']/ sp500_data[date]['5. adjusted close']) *100
#
# TypeError: 'DatetimeIndex' object is not callable
